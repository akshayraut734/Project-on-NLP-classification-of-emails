# %% [markdown]
# #PROJECT 62
#
#
# ---
#
# **NATURAL LANGUAGE PROCESSING**
#
# > *NLP of Emails*
#
#
# ---
# **Business Objective**
#
# *  In any organization an  inappropriate email will demotivate and spoil the positive environment which leads to more attrition rate and low productivity.
# *  Inappropriate emails could be form of bullying, racism, sexual favoritism and hate in the gender or culture.
# *  In today's world so dominated by email no organization is immune to these hate emails.
# *   ***The main goal of this project is to build a model to identify  emails as abusive or non abusive  on the given day based on the above inappropriate content.***
# ---

# %%
# Importing requried modules

# %%
# !pip install fasttext

# %%
# !pip install contractions

# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import seaborn as sns 
import nltk
import string
import fasttext
import contractions
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords, wordnet
from nltk.stem import WordNetLemmatizer
plt.xticks(rotation=70)
pd.options.mode.chained_assignment = None
pd.set_option('display.max_colwidth', 100)
# %matplotlib inline
from sklearn.feature_extraction.text import CountVectorizer

# %%
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from textblob import TextBlob

import collections

# %% [markdown]
# ## LOADING AND ANALYSING DATA

# %%
# LOADING DATASET

# %%
# First 5 datapoints and Last 5 datapoints

# %% [markdown]
# *   **Viewing first and last 5 datapoints for understanding the structure of dataset, variables in  dataset and datatypes of variables weather they are object or float or data-time or integer.**
# *   **Here we can see there are 4 main variables in our dataset-filename,Message-ID,content and Class.**

# %%
dat=pd.read_csv('/content/drive/MyDrive/Project P62/Emails.csv')
dat.head()
# Out:
#    Unnamed: 0  ...    Class
# 0           0  ...  Abusive
# 1           1  ...  Abusive
# 2           2  ...  Abusive
# 3           3  ...  Abusive
# 4           4  ...  Abusive
#
# [5 rows x 5 columns]

# %%
dat.tail()
# Out:
#        Unnamed: 0  ...        Class
# 48071       48071  ...  Non Abusive
# 48072       48072  ...  Non Abusive
# 48073       48073  ...  Non Abusive
# 48074       48074  ...  Non Abusive
# 48075       48075  ...  Non Abusive
#
# [5 rows x 5 columns]

# %%
# Droping the unwanted column from dataset
dat.drop('Unnamed: 0', axis=1, inplace=True)

# %%
# Information about dataset

# %%
dat.columns
# Out:
# Index(['filename', 'Message-ID', 'content', 'Class'], dtype='object')

# %% [markdown]
# VARIABLES-
#
# *Variable names and their descriptions are as follows*
#
# 1.   **Filename** - It is the name of file from where the content of mail is extracted.
#
# 2.   **Message-ID**- It is the ID related to the file or mail that we have extracted.
# 3. **Content**- It is the text in the mail with respect to particular Message-ID and Filename.
# 4. **Class**- It is a kind of  classification column for particular mail weather it has Abusive or Non abbusive content.

# %%
# Dataset has 48076 datapoints and 4 columns

# %%
dat.shape
# Out:
# (48076, 4)

# %%
dat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48076 entries, 0 to 48075
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   filename    48076 non-null  object
#  1   Message-ID  48076 non-null  object
#  2   content     48076 non-null  object
#  3   Class       48076 non-null  object
# dtypes: object(4)
# memory usage: 1.5+ MB

# %% [markdown]
# *   Our data is in form of DataFrame not as arry or list or dictionary format
#
# *   There are totally 48076 mails or entries.
#
#
# *   All the columns are object datatype and they are classified correctly as we can see from variables description they are not numerical data.
#
# *   There are no Null entries or NaN values in our dataset.

# %%
# No.of Unique values/entries in Message-ID column
# As it is a ID every entry is a unique value

# %%
dat['Message-ID'].nunique()
# Out:
# 48076

# %%
# No.of Unique values/entries in filename column
# As it is a name of file every entry is a unique value

# %%
dat['filename'].nunique()
# Out:
# 48076

# %%
# No.of type of mail contents in dataset
# Here we can see there are nearly half of the mails are haveing same  stop words,nouns and verbs etc,.

# %%
dat['content'].nunique()
# Out:
# 24656

# %%
# No.of Unique values in Class column and their counts

# %%
dat['Class'].value_counts()
# Out:
# Non Abusive    44666
# Abusive         3410
# Name: Class, dtype: int64

# %%
# Countplot for unique values in Class variable
sns.countplot(dat.Class);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
da = dat.drop(columns=[ 'filename', 'Message-ID'], axis=1)
da.head()
# Out:
#                                                                                                content    Class
# 0  eat shit\n\n\n\n\nJohn J Lavorato@excelr\n11/18/2000 01:01 PM\nTo: John Arnold/HOU/ECT@ECT\ncc: ...  Abusive
# 1                                                                                             fuck you  Abusive
# 2  Gentlemen:\nThe following champagne is available at 70% of approximate retail price. Also \nhave...  Abusive
# 3  sorry i've taken so long...just been trying to fend off the chicks.   life is \nsooooo hard some...  Abusive
# 4  asshole\n\n\n\n\nJohn J Lavorato@excelr\n12/23/2000 10:51 AM\nTo: John Arnold/HOU/ECT@ECT\ncc:  ...  Abusive

# %%
abusive = da[da["Class"]=="Abusive"]
abusive.shape
# Out:
# (3410, 2)

# %%
non_abusive = da[da["Class"]=="Non Abusive"]
non_abusive.shape
# Out:
# (44666, 2)

# %%
# Removing duplicate datapoints from non_abusive dataframe 
# Here we are removing duplicates olny from non_abusive dataframe because given data is imbalance with less No.of abusive emails

# %%
non_abusive1 = non_abusive.drop_duplicates()
non_abusive1.shape
# Out:
# (23014, 2)

# %%
# Now the data is somewhat balanced than before

# %%
print("Abusive ", len(abusive),"\n""Non Abusive ", len(non_abusive1))
# Out:
# Abusive  3410
# Non Abusive  23014

# %%
data = pd.concat([abusive,non_abusive1], axis=0, ignore_index=True)

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS (EDA)

# %% [markdown]
# ### Text Pre-Processing

# %% [markdown]
# #### Expanding Contractions

# %%
data['no_contract'] = data['content'].apply(lambda x: [contractions.fix(word) for word in x.split()])

# %%
data['content_str'] = [' '.join(map(str, l)) for l in data['no_contract']]

# %%
data[['content','content_str']].head()
# Out:
#                                                                                                content                                                                                          content_str
# 0  eat shit\n\n\n\n\nJohn J Lavorato@excelr\n11/18/2000 01:01 PM\nTo: John Arnold/HOU/ECT@ECT\ncc: ...  eat shit John J Lavorato@excelr 11/18/2000 01:01 PM To: John Arnold/HOU/ECT@ECT cc: Subject: Foo...
# 1                                                                                             fuck you                                                                                             fuck you
# 2  Gentlemen:\nThe following champagne is available at 70% of approximate retail price. Also \nhave...  Gentlemen: The following champagne is available at 70% of approximate retail price. Also have in...
# 3  sorry i've taken so long...just been trying to fend off the chicks.   life is \nsooooo hard some...  sorry I have taken so long...just been trying to fend off the chicks. life is sooooo hard someti...
# 4  asshole\n\n\n\n\nJohn J Lavorato@excelr\n12/23/2000 10:51 AM\nTo: John Arnold/HOU/ECT@ECT\ncc:  ...  asshole John J Lavorato@excelr 12/23/2000 10:51 AM To: John Arnold/HOU/ECT@ECT cc: Subject: john...

# %% [markdown]
# 1.  Contractions are the little literary shortcuts, where we use "Should’ve" insted of "should have" , "Don't" insted of "Do Not" this contrction function expand those shortcuts.
# 2.  We are going to add a new column to our dataframe called 'content_str' and apply contraction function to 'content' column which will expand any contractions
# 3. In the 4th row we can see "i've" is expanded to "i have".

# %% [markdown]
# #### Removing Punctuations

# %%
data['no_punc'] = data['content_str'].str.replace('[^\w\s]','')
data.iloc[:,2:].head()
# Out:
#                                                                                            no_contract  ...                                                                                              no_punc
# 0  [eat, shit, John, J, Lavorato@excelr, 11/18/2000, 01:01, PM, To:, John, Arnold/HOU/ECT@ECT, cc:,...  ...  eat shit John J Lavoratoexcelr 11182000 0101 PM To John ArnoldHOUECTECT cc Subject Football bets...
# 1                                                                                          [fuck, you]  ...                                                                                             fuck you
# 2  [Gentlemen:, The, following, champagne, is, available, at, 70%, of, approximate, retail, price.,...  ...  Gentlemen The following champagne is available at 70 of approximate retail price Also have inter...
# 3  [sorry, I have, taken, so, long...just, been, trying, to, fend, off, the, chicks., life, is, soo...  ...  sorry I have taken so longjust been trying to fend off the chicks life is sooooo hard sometimes ...
# 4  [asshole, John, J, Lavorato@excelr, 12/23/2000, 10:51, AM, To:, John, Arnold/HOU/ECT@ECT, cc:, S...  ...  asshole John J Lavoratoexcelr 12232000 1051 AM To John ArnoldHOUECTECT cc Subject john I cannot ...
#
# [5 rows x 3 columns]

# %% [markdown]
# #### Tokenization

# %%
# Tokenization of the string i.e divding the string into separate words

# %%
data['tokenized'] = data['no_punc'].apply(word_tokenize)
data.iloc[:,2:].head()
# Out:
#                                                                                            no_contract  ...                                                                                            tokenized
# 0  [eat, shit, John, J, Lavorato@excelr, 11/18/2000, 01:01, PM, To:, John, Arnold/HOU/ECT@ECT, cc:,...  ...  [eat, shit, John, J, Lavoratoexcelr, 11182000, 0101, PM, To, John, ArnoldHOUECTECT, cc, Subject,...
# 1                                                                                          [fuck, you]  ...                                                                                          [fuck, you]
# 2  [Gentlemen:, The, following, champagne, is, available, at, 70%, of, approximate, retail, price.,...  ...  [Gentlemen, The, following, champagne, is, available, at, 70, of, approximate, retail, price, Al...
# 3  [sorry, I have, taken, so, long...just, been, trying, to, fend, off, the, chicks., life, is, soo...  ...  [sorry, I, have, taken, so, longjust, been, trying, to, fend, off, the, chicks, life, is, sooooo...
# 4  [asshole, John, J, Lavorato@excelr, 12/23/2000, 10:51, AM, To:, John, Arnold/HOU/ECT@ECT, cc:, S...  ...  [asshole, John, J, Lavoratoexcelr, 12232000, 1051, AM, To, John, ArnoldHOUECTECT, cc, Subject, j...
#
# [5 rows x 4 columns]

# %% [markdown]
# #### Converting all Characters to Lowercase

# %%
# Converting Uppercase letters to Lowercase

# %%
data['lower'] = data['tokenized'].apply(lambda x: [word.lower() for word in x])
data.iloc[:,2:].head()
# Out:
#                                                                                            no_contract  ...                                                                                                lower
# 0  [eat, shit, John, J, Lavorato@excelr, 11/18/2000, 01:01, PM, To:, John, Arnold/HOU/ECT@ECT, cc:,...  ...  [eat, shit, john, j, lavoratoexcelr, 11182000, 0101, pm, to, john, arnoldhouectect, cc, subject,...
# 1                                                                                          [fuck, you]  ...                                                                                          [fuck, you]
# 2  [Gentlemen:, The, following, champagne, is, available, at, 70%, of, approximate, retail, price.,...  ...  [gentlemen, the, following, champagne, is, available, at, 70, of, approximate, retail, price, al...
# 3  [sorry, I have, taken, so, long...just, been, trying, to, fend, off, the, chicks., life, is, soo...  ...  [sorry, i, have, taken, so, longjust, been, trying, to, fend, off, the, chicks, life, is, sooooo...
# 4  [asshole, John, J, Lavorato@excelr, 12/23/2000, 10:51, AM, To:, John, Arnold/HOU/ECT@ECT, cc:, S...  ...  [asshole, john, j, lavoratoexcelr, 12232000, 1051, am, to, john, arnoldhouectect, cc, subject, j...
#
# [5 rows x 5 columns]

# %% [markdown]
# #### Number of stopwords

# %%
# Adding a column "stopwords" which shows the count of stopwords in the text.

# %%
stop = stopwords.words('english')

data['stopwords'] = data['content_str'].apply(lambda x: len([x for x in x.split() if x in stop]))
data.iloc[:,4:].head()
# Out:
#                                                                                                no_punc  ... stopwords
# 0  eat shit John J Lavoratoexcelr 11182000 0101 PM To John ArnoldHOUECTECT cc Subject Football bets...  ...         1
# 1                                                                                             fuck you  ...         1
# 2  Gentlemen The following champagne is available at 70 of approximate retail price Also have inter...  ...        11
# 3  sorry I have taken so longjust been trying to fend off the chicks life is sooooo hard sometimes ...  ...        24
# 4  asshole John J Lavoratoexcelr 12232000 1051 AM To John ArnoldHOUECTECT cc Subject john I cannot ...  ...         2
#
# [5 rows x 4 columns]

# %% [markdown]
# #### Removing Stopwords

# %%
stop_words = set(stopwords.words('english'))
data['stopwords_removed'] = data['lower'].apply(lambda x: [word for word in x if word not in stop_words])
data.iloc[:,4:].head()
# Out:
#                                                                                                no_punc  ...                                                                                    stopwords_removed
# 0  eat shit John J Lavoratoexcelr 11182000 0101 PM To John ArnoldHOUECTECT cc Subject Football bets...  ...  [eat, shit, john, j, lavoratoexcelr, 11182000, 0101, pm, john, arnoldhouectect, cc, subject, foo...
# 1                                                                                             fuck you  ...                                                                                               [fuck]
# 2  Gentlemen The following champagne is available at 70 of approximate retail price Also have inter...  ...  [gentlemen, following, champagne, available, 70, approximate, retail, price, also, interest, tra...
# 3  sorry I have taken so longjust been trying to fend off the chicks life is sooooo hard sometimes ...  ...  [sorry, taken, longjust, trying, fend, chicks, life, sooooo, hard, sometimes, monkey, brian, oro...
# 4  asshole John J Lavoratoexcelr 12232000 1051 AM To John ArnoldHOUECTECT cc Subject john I cannot ...  ...  [asshole, john, j, lavoratoexcelr, 12232000, 1051, john, arnoldhouectect, cc, subject, john, see...
#
# [5 rows x 5 columns]

# %% [markdown]
# #### Number of words

# %%
#Number of Words in single email
data['word_count'] = data['stopwords_removed'].apply(lambda x: len(str(x).split(" ")))
data.iloc[:,4:].head()
# Out:
#                                                                                                no_punc  ... word_count
# 0  eat shit John J Lavoratoexcelr 11182000 0101 PM To John ArnoldHOUECTECT cc Subject Football bets...  ...         35
# 1                                                                                             fuck you  ...          1
# 2  Gentlemen The following champagne is available at 70 of approximate retail price Also have inter...  ...         77
# 3  sorry I have taken so longjust been trying to fend off the chicks life is sooooo hard sometimes ...  ...         39
# 4  asshole John J Lavoratoexcelr 12232000 1051 AM To John ArnoldHOUECTECT cc Subject john I cannot ...  ...         27
#
# [5 rows x 6 columns]

# %% [markdown]
# #### Number of Characters

# %%
#Number of characters in single email 
data['char_count'] = data['no_punc'].str.len() 
data.iloc[:,4:].head()
# Out:
#                                                                                                no_punc  ... char_count
# 0  eat shit John J Lavoratoexcelr 11182000 0101 PM To John ArnoldHOUECTECT cc Subject Football bets...  ...        182
# 1                                                                                             fuck you  ...          8
# 2  Gentlemen The following champagne is available at 70 of approximate retail price Also have inter...  ...        545
# 3  sorry I have taken so longjust been trying to fend off the chicks life is sooooo hard sometimes ...  ...        387
# 4  asshole John J Lavoratoexcelr 12232000 1051 AM To John ArnoldHOUECTECT cc Subject john I cannot ...  ...        175
#
# [5 rows x 7 columns]

# %% [markdown]
# #### Stemming

# %%
'''
The idea of stemming is to reduce different forms of word usage into its root word.
For example, “drive”, “drove”, “driving”, “driven”, “driver” are derivatives of the word “drive”.so stemming function converts the words to 
their rootwords.
 
 '''
# Out:
# '\nThe idea of stemming is to reduce different forms of word usage into its root word.\nFor example, “drive”, “drove”, “driving”, “driven”, “driver” are derivatives of the word “drive”.so stemming function converts the words to \ntheir rootwords.\n \n '

# %%
data['stp_rem_str'] = [' '.join(map(str, l)) for l in data['stopwords_removed']]

# %%
from nltk.stem import PorterStemmer
st = PorterStemmer()
data['stemmi']=data['stp_rem_str'].apply(lambda x: " ".join([st.stem(word) for word in x.split()]))

# %%
data.iloc[:,4:].head()
# Out:
#                                                                                                no_punc  ...                                                                                               stemmi
# 0  eat shit John J Lavoratoexcelr 11182000 0101 PM To John ArnoldHOUECTECT cc Subject Football bets...  ...  eat shit john j lavoratoexcelr 11182000 0101 pm john arnoldhouectect cc subject footbal bet 200 ...
# 1                                                                                             fuck you  ...                                                                                                 fuck
# 2  Gentlemen The following champagne is available at 70 of approximate retail price Also have inter...  ...  gentlemen follow champagn avail 70 approxim retail price also interest trade red wine retail pri...
# 3  sorry I have taken so longjust been trying to fend off the chicks life is sooooo hard sometimes ...  ...  sorri taken longjust tri fend chick life sooooo hard sometim monkey brian orourkeexcelr commun 0...
# 4  asshole John J Lavoratoexcelr 12232000 1051 AM To John ArnoldHOUECTECT cc Subject john I cannot ...  ...  asshol john j lavoratoexcelr 12232000 1051 john arnoldhouectect cc subject john seem make gambl ...
#
# [5 rows x 9 columns]

# %% [markdown]
# #### Lemmatization

# %%
'''
lemmatization is a similar method as stemming but by lemmatization proces we will find the morphological rootwords.

'''
# Out:
# '\nlemmatization is a similar method as stemming but by lemmatization proces we will find the morphological rootwords.\n\n'

# %%
from textblob import Word

# %%
data['lemma'] = data['stemmi'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))

# %%
data[['stemmi','lemma']].head()
# Out:
#                                                                                                 stemmi                                                                                                lemma
# 0  eat shit john j lavoratoexcelr 11182000 0101 pm john arnoldhouectect cc subject footbal bet 200 ...  eat shit john j lavoratoexcelr 11182000 0101 pm john arnoldhouectect cc subject footbal bet 200 ...
# 1                                                                                                 fuck                                                                                                 fuck
# 2  gentlemen follow champagn avail 70 approxim retail price also interest trade red wine retail pri...  gentleman follow champagn avail 70 approxim retail price also interest trade red wine retail pri...
# 3  sorri taken longjust tri fend chick life sooooo hard sometim monkey brian orourkeexcelr commun 0...  sorri taken longjust tri fend chick life sooooo hard sometim monkey brian orourkeexcelr commun 0...
# 4  asshol john j lavoratoexcelr 12232000 1051 john arnoldhouectect cc subject john seem make gambl ...  asshol john j lavoratoexcelr 12232000 1051 john arnoldhouectect cc subject john seem make gambl ...

# %% [markdown]
# #### Removing Numbers

# %%
import re

# %%
# Removing numbers form text
data['cleaned']=data['lemma'].apply(lambda x: re.sub('\w*\d\w*','', x))

# %%
data.iloc[:,-2:].head()
# Out:
#                                                                                                  lemma                                                                                              cleaned
# 0  eat shit john j lavoratoexcelr 11182000 0101 pm john arnoldhouectect cc subject footbal bet 200 ...  eat shit john j lavoratoexcelr   pm john arnoldhouectect cc subject footbal bet  minn  buff  phi...
# 1                                                                                                 fuck                                                                                                 fuck
# 2  gentleman follow champagn avail 70 approxim retail price also interest trade red wine retail pri...  gentleman follow champagn avail  approxim retail price also interest trade red wine retail price...
# 3  sorri taken longjust tri fend chick life sooooo hard sometim monkey brian orourkeexcelr commun 0...  sorri taken longjust tri fend chick life sooooo hard sometim monkey brian orourkeexcelr commun  ...
# 4  asshol john j lavoratoexcelr 12232000 1051 john arnoldhouectect cc subject john seem make gambl ...  asshol john j lavoratoexcelr   john arnoldhouectect cc subject john seem make gambl problem go a...

# %% [markdown]
# #### Sentiment Analysis

# %%
'''
Assining a polarity value for the text which ranges for -1 to 1 which describes the negativity and positiviy of the text.
Adding a column 'senti_polar' which shows the polarity value.
'''
# Out:
# "\nAssining a polarity value for the text which ranges for -1 to 1 which describes the negativity and positiviy of the text.\nAdding a column 'senti_polar' which shows the polarity value.\n"

# %%
data['senti_polar'] = data['lemma'].apply(lambda x: TextBlob(x).sentiment.polarity )

# %%
data[['content','Class','senti_polar']].tail()
# Out:
#                                                                                                    content  ... senti_polar
# 26419   Do you need new leads for your business ?\n Do you need increased Internet Exposure ?\n\n Thous...  ...    0.174825
# 26420  [IMAGE]\n  [IMAGE]     [IMAGE] GARTH BROOKS  "Wrapped Up In You"    [IMAGE] [IMAGE] =\n         ...  ...    0.298295
# 26421  \n[IMAGE][IMAGE][IMAGE] \nDear SmartReminders member,\n[IMAGE]\t\n\n\n      FranChoice is a free...  ...    0.105844
# 26422  \n[IMAGE]\n  [IMAGE]   [IMAGE]    [IMAGE] KID ROCK  "Forever"  [IMAGE]     Official Kid Rock Sit...  ...    0.100812
# 26423  \nYou received this e-mail because you registered on the E*TRADE Web site,  or on one of our par...  ...    0.141234
#
# [5 rows x 3 columns]

# %% [markdown]
# ### Visualizations

# %%
data_abu=data.loc[data['Class'] == 'Abusive']
data_nabu=data.loc[data['Class']=='Non Abusive']

# %% [markdown]
# #### Histogram of Sentiment polarity range

# %%
plt.figure(figsize=(20,10))
plt.margins(0.04)
plt.xlabel('Sentiment', fontsize=15)
plt.xticks(fontsize=20)
plt.ylabel('Frequency', fontsize=15)
plt.yticks(fontsize=20)
plt.hist(data['senti_polar'], bins=50)
plt.title('Sentiment Distribution', fontsize=20)
plt.show()

# %%
'''

The above histogram is skewed to towards posivtive polarity as we know there are more Non abusive mails than abusive mails
in our data.

'''

# %%
# Histogram for Sentiment polarity range for Abusive and Non Abusive emails.

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
plt.hist(data_abu['senti_polar'], bins=80,color='r',);
plt.title('Sentiment polarity of Abusive class')
plt.xlabel('Polarity')
plt.ylabel('No.of emails')
plt.subplot(1,2,2)
plt.hist(data_nabu['senti_polar'], bins=50,color='g');
plt.title('Sentiment polarity of Non Abusive class')
plt.xlabel('Polarity')
plt.ylabel('No.of emails')
# Out:
# Text(0, 0.5, 'No.of emails')

# %% [markdown]
# #### Wordcloud

# %%
'''
Wordcolud for top 100 most used words in the emails . The size of the words is directly propotional to the uasage of words.
'''

# %%
# Import packages
import matplotlib.pyplot as plt
# %matplotlib inline
from wordcloud import WordCloud, STOPWORDS
# Define a function to plot word cloud
def plot_cloud(wordcloud):
    # Set figure size
    plt.figure(figsize=(40, 30))
    # Display image
    plt.imshow(wordcloud) 
    # No axis details
    plt.axis("off");

# %%
# Joining the list into one string/text
text = ' '.join(data['stp_rem_str'])

# %%
# Generate wordcloud
stopwords = STOPWORDS
stopwords.add('will')
wordcloud = WordCloud(width = 3000, height = 2000, background_color='black', max_words=100,colormap='Set2',stopwords=stopwords).generate(text)
# Plot
plot_cloud(wordcloud)

# %% [markdown]
# #### Bargraph of Top 25 most used words in emails.

# %%
email=np.array(data_nabu['cleaned'])
s=str(email)
nabu_toc = word_tokenize(s)
print(nabu_toc)
# Out:
# ['[', "'forecast'", "'travel", 'busi', 'meet', 'take', 'fun', 'trip', 'especi', 'prepar', 'present', 'would', 'suggest', 'hold', 'busi', 'plan', 'meet', 'take', 'trip', 'without', 'formal', 'busi', 'meet', 'would', 'even', 'tri', 'get', 'honest', 'opinion', 'whether', 'trip', 'even', 'desir', 'necessari', 'far', 'busi', 'meet', 'think', 'would', 'product', 'tri', 'stimul', 'discus', 'across', 'differ', 'group', 'work', 'often', 'present', 'speak', 'other', 'quiet', 'wait', 'turn', 'meet', 'might', 'better', 'held', 'round', 'tabl', 'discus', 'format', 'suggest', 'go', 'austin', 'play', 'golf', 'rent', 'ski', 'boat', 'jet', 'ski', 'fli', 'somewher', 'take', 'much', "time'", "'test", 'success', 'way', 'go', "'", '...', "'imageimageimag", 'dear', 'smartremind', 'member', 'imag', 'franchoic', 'free', 'oneonon', 'consult', 'servic', 'peopl', 'look', 'purchas', 'franchis', 'busi', 'help', 'hundr', 'new', 'entrepreneur', 'save', 'time', 'research', 'right', 'opportun', 'discov', 'prescreen', 'franchis', 'compani', 'would', 'success', 'avoid', 'costli', 'devast', 'mistak', 'think', 'own', 'busi', 'least', 'net', 'worth', 'invest', 'franchis', 'live', 'unit', 'state', 'owe', 'learn', 'uniqu', 'servic', 'imag', 'imag', 'imag', 'respect', 'privaci', 'certifi', 'particip', 'bbbonlin', 'privaci', 'program', 'remov', 'futur', 'offersclick', 'smartreminderscom', 'permiss', 'base', 'servic', 'unsubscrib', "click'", "'imag", 'imag', 'imag', 'imag', 'kid', 'rock', 'forev', 'imag', 'offici', 'kid', 'rock', 'site', 'wwwkidrockcom', 'time', 'get', 'cocki', 'hey', 'launcher', 'muchanticip', 'followup', 'kid', 'rock', 'ten', 'millionsel', 'devil', 'without', 'due', 'store', 'novemb', 'cocki', 'find', 'kid', 'rock', 'best', 'mix', 'mani', 'music', 'style', 'creat', 'uniqu', 'brand', 'rock', 'n', 'roll', 'kind', 'sonic', 'assault', 'blew', 'radio', 'mtv', 'hit', 'like', 'bawitdaba', 'cowboy', 'god', 'know', 'american', 'bad', 'as', 'check', 'hot', 'new', 'video', 'forev', 'feel', 'red', 'white', 'blue', 'stay', 'tune', 'launch', 'p', 'cocki', 'hit', 'store', 'novemb', 'preorder', 'album', 'yahoo', 'shop', 'today', 'first', 'get', 'album', 'save', 'money', 'plea', 'unsubscrib', 'prefer', 'receiv', 'futur', 'email', 'launch', 'medium', "inc'", "'receiv", 'email', 'regist', 'etrad', 'web', 'site', 'one', 'partner', 'site', 'want', 'receiv', 'partner', 'email', 'offer', 'etrad', 'market', 'email', 'opt', 'chang', 'prefer', 'subscrib', 'lcampbelexcelrcom', 'imag', 'imag', 'imag', 'imag', 'imag', 'imag', 'imag', 'imag', 'imag', 'imag', 'imag', 'imag', 'imag', 'imag', 'imag', 'imag', 'imag', 'imag', 'everyth', 'love', 'internet', 'imag', 'imag', 'imag', 'imag', 'imag', 'imag', 'much', 'much', 'faster', 'imag', 'imag', 'etrad', 'member', 'make', 'jump', 'dsl', 'save', 'imag', 'imag', 'imag', 'know', 'internet', 'surf', 'email', 'even', 'instant', 'messag', 'mani', 'way', 'internet', 'made', 'life', 'easier', 'better', 'enjoy', 'current', 'onlin', 'experi', 'begin', 'imagin', 'web', 'page', 'pop', 'instantli', 'stream', 'video', 'music', 'softwar', 'download', 'fraction', 'time', 'use', 'earthlink', 'dsl', 'give', 'connect', 'time', 'faster', 'dialup', 'allow', 'le', 'time', 'imagin', 'get', 'onlin', 'right', 'away', 'without', 'dialup', 'delay', 'earthlink', 'dsl', 'give', 'alwayson', 'connect', 'internet', 'whenev', 'comput', 'imagin', 'surf', 'net', 'talk', 'phone', 'time', 'need', 'second', 'phone', 'line', 'make', 'call', 'take', 'call', 'even', 'fax', 'onlin', 'imag', 'make', 'jump', 'earthlink', 'dsl', 'get', 'special', 'packag', 'includ', 'imag', 'imag', 'imag', 'free', 'dsl', 'modem', 'equip', 'softwar', 'valu', 'imag', 'email', 'box', 'account', 'imag', 'special', 'earthlink', 'subscrib', 'benefit', 'imag', 'imag', 'unlimit', 'highspe', 'dsl', 'access', 'month', 'imag', 'imag', 'save', 'earthlink', 'free', 'selfinstal', 'kit', 'shown', 'left', 'imag', 'imag', 'imag', 'imag', 'get', 'first', 'month', 'dsl', 'servic', 'earthlink', 'price', 'valu', 'ima ...

# %%
email_ab=np.array(data_abu['cleaned'])
s=str(email_ab)
abu_toc = word_tokenize(s)
print(abu_toc)
# Out:
# ['[', "'eat", 'shit', 'john', 'j', 'lavoratoexcelr', 'pm', 'john', 'arnoldhouectect', 'cc', 'subject', 'footbal', 'bet', 'minn', 'buff', 'phil', 'indi', 'cinnci', 'det', 'clev', 'den', 'dall', 'jack', "'", "'fuck'", "'gentleman", 'follow', 'champagn', 'avail', 'approxim', 'retail', 'price', 'also', 'interest', 'trade', 'red', 'wine', 'retail', 'price', 'deriv', 'spec', 'websit', 'winesearcercom', 'wine', 'store', 'temperatur', 'control', 'privat', 'wine', 'storag', 'facil', 'quan', 'vintag', 'wine', 'retail', 'perrier', 'jouet', 'brut', 'fleur', 'de', 'champagn', 'piper', 'heidsek', 'reserv', 'dom', 'perignon', 'veuv', 'cliquot', 'ponsardin', 'la', 'grand', 'dame', 'taitteng', 'millesin', 'brut', 'jacquart', 'millesin', 'roeder', 'cristal', "interest'", '...', "'got", 'late', 'friday', 'ever', 'heard', 'origin', 'messag', 'jeff', 'lawson', 'mailtojeffreyskillingyahoocom', 'sent', 'wednesday', 'novemb', 'pm', 'zipper', 'andi', 'subject', 'fuck', 'piec', 'shit', 'wait', 'see', 'go', 'ship', 'like', 'vermin', 'smug', 'paranoid', 'unhappi', 'mother', 'fucker', 'eat', 'shit', '__________________________________________________', 'yahoo', 'yahoo', 'geociti', 'quick', 'easi', 'web', 'site', 'host', "'", "'origin", 'messag', 'engelhardt', 'matthew', 'maengelhardtcollinsbarrowcomexcelr', 'sent', 'friday', 'januari', 'pm', 'dorland', 'chri', 'dorland', 'dan', 'kbibbi', 'email', 'max', 'zureski', 'ca', 'calgari', 'email', 'mike', 'georg', 'email', 'nate', 'dogg', 'email', 'colin', 'clement', 'ca', 'calgari', 'email', 'subject', 'fw', 'rule', 'manhood', 'origin', 'messag', 'yee', 'colin', 'sent', 'friday', 'januari', 'alder', 'doug', 'bain', 'staci', 'engelhardt', 'matthew', 'maxwel', 'tara', 'simpson', 'regan', 'steink', 'nathan', 'tymofichuk', 'christin', 'subject', 'fw', 'rule', 'manhood', 'origin', 'messag', 'colin', 'yee', 'mailtocmyeehomecom', 'sent', 'thursday', 'januari', 'pm', 'mandmmittonshawca', 'cmyeecollinsbarrowcom', 'we', 'giebelhau', 'subject', 'fw', 'rule', 'manhood', 'rule', 'manhood', 'thou', 'shall', 'rent', 'movi', 'chocolat', 'black', 'jack', 'alway', 'split', 'ace', 'eight', 'argument', 'circumst', 'may', 'two', 'men', 'share', 'umbrella', 'man', 'bring', 'camera', 'bachelor', 'parti', 'may', 'legal', 'kill', 'eaten', 'fellow', 'partygo', 'queri', 'buddi', 'wife', 'girlfriend', 'mother', 'father', 'priest', 'shrink', 'dentist', 'account', 'dog', 'walker', 'need', 'provid', 'use', 'inform', 'whatsoev', 'whereabout', 'permit', 'deni', 'exist', 'unless', 'murder', 'someon', 'immedi', 'famili', 'must', 'bail', 'friend', 'jail', 'within', 'hour', 'may', 'exagger', 'anecdot', 'told', 'bar', 'percent', 'without', 'recrimin', 'beyond', 'anyon', 'within', 'earshot', 'allow', 'callbullshit', 'except', 'tryi', 'ng', 'pick', 'girl', 'allow', 'exagger', 'rate', 'rise', 'percent', 'known', 'guy', 'hour', 'sister', 'limit', 'forev', 'maximum', 'amount', 'time', 'wait', 'anoth', 'guy', 'run', 'late', 'minut', 'girl', 'requir', 'wait', 'minut', 'everi', 'point', 'hot', 'score', 'classic', 'scale', 'bitch', 'brand', 'free', 'beer', 'buddi', 'refriger', 'forbidden', 'may', 'gripe', 'temperatur', 'unsuit', 'man', 'ever', 'requir', 'buy', 'birthday', 'present', 'anoth', 'man', 'fact', 'even', 'rememb', 'friend', 'birthday', 'strictli', 'option', 'agre', 'distract', 'ugli', 'friend', 'hot', 'babe', 'buddi', 'tri', 'hook', 'legal', 'duti', 'get', 'carri', 'away', 'good', 'deed', 'end', 'sex', 'beast', 'pal', 'forbidden', 'speak', 'even', 'bachelor', 'parti', 'date', 'buddi', 'ex', 'requir', 'ask', 'permiss', 'return', 'requir', 'grant', 'woman', 'claim', 'love', 'watch', 'sport', 'must', 'treat', 'spi', 'demonstr', 'knowledg', 'game', 'abil', 'pick', 'buffalo', 'wing', 'clean', 'man', 'zipper', 'problem', 'see', 'noth', 'univers', 'compens', 'buddi', 'help', 'move', 'beer', 'man', 'must', 'never', 'cat', 'like', 'girlfriend', 'cat', 'girlfriend', 'must', 'bond', 'buddi', 'girlfriend', 'within', 'minut', 'meet', 'howev', 'requir', 'make',  ...

# %%
from nltk.probability import FreqDist
mostcommon_1 = FreqDist(nabu_toc).most_common(25)
x, y = zip(*mostcommon_1)
mostcommon_2 =FreqDist(abu_toc).most_common(25)
x1, y1 = zip(*mostcommon_2)
plt.figure(figsize=(50,25))
plt.margins(0.02)
plt.subplot(2,1,1)
plt.bar(x, y)
plt.xlabel('Words', fontsize=20)
plt.ylabel('Frequency of Words', fontsize=20)
plt.yticks(fontsize=20)
plt.xticks(rotation=60, fontsize=20)
plt.title('Frequency of 25 Most Common Words of Non Abusive Emails', fontsize=30)
plt.subplot(2,1,2)
plt.bar(x1, y1)
plt.xlabel('Words', fontsize=20)
plt.ylabel('Frequency of Words', fontsize=20)
plt.yticks(fontsize=20)
plt.xticks(rotation=60, fontsize=20)
plt.title('Frequency of 25 Most Common Words Abusive Emails', fontsize=30)
plt.show()

# %%
# Top 25 words in all the emails in our data

# %%
email_all=np.array(data['cleaned'])
s=str(email_all)
all_toc = word_tokenize(s)
print(all_toc)
# Out:
# ['[', "'eat", 'shit', 'john', 'j', 'lavoratoexcelr', 'pm', 'john', 'arnoldhouectect', 'cc', 'subject', 'footbal', 'bet', 'minn', 'buff', 'phil', 'indi', 'cinnci', 'det', 'clev', 'den', 'dall', 'jack', "'", "'fuck'", "'gentleman", 'follow', 'champagn', 'avail', 'approxim', 'retail', 'price', 'also', 'interest', 'trade', 'red', 'wine', 'retail', 'price', 'deriv', 'spec', 'websit', 'winesearcercom', 'wine', 'store', 'temperatur', 'control', 'privat', 'wine', 'storag', 'facil', 'quan', 'vintag', 'wine', 'retail', 'perrier', 'jouet', 'brut', 'fleur', 'de', 'champagn', 'piper', 'heidsek', 'reserv', 'dom', 'perignon', 'veuv', 'cliquot', 'ponsardin', 'la', 'grand', 'dame', 'taitteng', 'millesin', 'brut', 'jacquart', 'millesin', 'roeder', 'cristal', "interest'", '...', "'imageimageimag", 'dear', 'smartremind', 'member', 'imag', 'franchoic', 'free', 'oneonon', 'consult', 'servic', 'peopl', 'look', 'purchas', 'franchis', 'busi', 'help', 'hundr', 'new', 'entrepreneur', 'save', 'time', 'research', 'right', 'opportun', 'discov', 'prescreen', 'franchis', 'compani', 'would', 'success', 'avoid', 'costli', 'devast', 'mistak', 'think', 'own', 'busi', 'least', 'net', 'worth', 'invest', 'franchis', 'live', 'unit', 'state', 'owe', 'learn', 'uniqu', 'servic', 'imag', 'imag', 'imag', 'respect', 'privaci', 'certifi', 'particip', 'bbbonlin', 'privaci', 'program', 'remov', 'futur', 'offersclick', 'smartreminderscom', 'permiss', 'base', 'servic', 'unsubscrib', "click'", "'imag", 'imag', 'imag', 'imag', 'kid', 'rock', 'forev', 'imag', 'offici', 'kid', 'rock', 'site', 'wwwkidrockcom', 'time', 'get', 'cocki', 'hey', 'launcher', 'muchanticip', 'followup', 'kid', 'rock', 'ten', 'millionsel', 'devil', 'without', 'due', 'store', 'novemb', 'cocki', 'find', 'kid', 'rock', 'best', 'mix', 'mani', 'music', 'style', 'creat', 'uniqu', 'brand', 'rock', 'n', 'roll', 'kind', 'sonic', 'assault', 'blew', 'radio', 'mtv', 'hit', 'like', 'bawitdaba', 'cowboy', 'god', 'know', 'american', 'bad', 'as', 'check', 'hot', 'new', 'video', 'forev', 'feel', 'red', 'white', 'blue', 'stay', 'tune', 'launch', 'p', 'cocki', 'hit', 'store', 'novemb', 'preorder', 'album', 'yahoo', 'shop', 'today', 'first', 'get', 'album', 'save', 'money', 'plea', 'unsubscrib', 'prefer', 'receiv', 'futur', 'email', 'launch', 'medium', "inc'", "'receiv", 'email', 'regist', 'etrad', 'web', 'site', 'one', 'partner', 'site', 'want', 'receiv', 'partner', 'email', 'offer', 'etrad', 'market', 'email', 'opt', 'chang', 'prefer', 'subscrib', 'lcampbelexcelrcom', 'imag', 'imag', 'imag', 'imag', 'imag', 'imag', 'imag', 'imag', 'imag', 'imag', 'imag', 'imag', 'imag', 'imag', 'imag', 'imag', 'imag', 'imag', 'everyth', 'love', 'internet', 'imag', 'imag', 'imag', 'imag', 'imag', 'imag', 'much', 'much', 'faster', 'imag', 'imag', 'etrad', 'member', 'make', 'jump', 'dsl', 'save', 'imag', 'imag', 'imag', 'know', 'internet', 'surf', 'email', 'even', 'instant', 'messag', 'mani', 'way', 'internet', 'made', 'life', 'easier', 'better', 'enjoy', 'current', 'onlin', 'experi', 'begin', 'imagin', 'web', 'page', 'pop', 'instantli', 'stream', 'video', 'music', 'softwar', 'download', 'fraction', 'time', 'use', 'earthlink', 'dsl', 'give', 'connect', 'time', 'faster', 'dialup', 'allow', 'le', 'time', 'imagin', 'get', 'onlin', 'right', 'away', 'without', 'dialup', 'delay', 'earthlink', 'dsl', 'give', 'alwayson', 'connect', 'internet', 'whenev', 'comput', 'imagin', 'surf', 'net', 'talk', 'phone', 'time', 'need', 'second', 'phone', 'line', 'make', 'call', 'take', 'call', 'even', 'fax', 'onlin', 'imag', 'make', 'jump', 'earthlink', 'dsl', 'get', 'special', 'packag', 'includ', 'imag', 'imag', 'imag', 'free', 'dsl', 'modem', 'equip', 'softwar', 'valu', 'imag', 'email', 'box', 'account', 'imag', 'special', 'earthlink', 'subscrib', 'benefit', 'imag', 'imag', 'unlimit', 'highspe', 'dsl', 'access', 'month', 'imag', 'imag', 'save', 'earthlink', 'free', 'selfinstal', 'kit', 'shown', 'left', 'imag', 'imag', 'imag', 'imag', 'get', 'first', 'month', 'dsl',  ...

# %%
mostcommon_all = FreqDist(all_toc).most_common(25)
x_all, y_all = zip(*mostcommon_all)
plt.figure(figsize=(50,25))
plt.margins(0.02)
plt.bar(x_all, y_all)
plt.xlabel('Words', fontsize=50)
plt.ylabel('Frequency of Words', fontsize=50)
plt.yticks(fontsize=40)
plt.xticks(rotation=60, fontsize=40)
plt.title('Frequency of 25 Most Common Words all Emails in our data', fontsize=60)
plt.show()

# %% [markdown]
# #### Bi-Gram Chart

# %%
#Bi-gram
def get_top_n2_words(corpus, n=None):
    vec1 = CountVectorizer(ngram_range=(2,2),  #for tri-gram, put ngram_range=(3,3)
            max_features=2000).fit(corpus)
    bag_of_words = vec1.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in     
                  vec1.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], 
                reverse=True)
    return words_freq[:n]

# %%
# Top 20 Bi-gram words
top2_words = get_top_n2_words(data["cleaned"], n=200) #top 200
top2_df = pd.DataFrame(top2_words)
top2_df.columns=["Bi-gram", "Freq"]
top2_df.head(30)
# Out:
#                    Bi-gram  Freq
# 0            origin messag  9565
# 1               cc subject  5355
# 2                imag imag  4888
# 3                 let know  4825
# 4               would like  3375
# 5          trans_typ final  2761
# 6       mkt_type trans_dat  2582
# 7               subject fw  2323
# 8              final sc_id  2264
# 9                 new york  2141
# 10              sc_id epmi  2042
# 11                   tr td  2016
# 12             sent monday  2001
# 13            sent tuesday  1957
# 14            font faceari  1918
# 15          sched_typ engi  1897
# 16          engi purch_sal  1897
# 17             excelr corp  1839
# 18                plea let  1824
# 19           epmi mkt_type  1793
# 20    trans_dat trading_sc  1793
# 21  pnt_of_intrc sched_typ  1793
# 22       purch_sal deal_no  1793
# 23   faceari helveticafont  1749
# 24                data iso  1743
# 25                bad data  1741
# 26                hour bad  1740
# 27           iso trans_typ  1740
# 28               last week  1706
# 29             posit activ  1611

# %%
#Bi-gram plot
import matplotlib.pyplot as plt
import seaborn as sns
top20_bigram = top2_df.iloc[0:20,:]
fig = plt.figure(figsize = (20, 5))
plot=sns.barplot(x=top20_bigram["Bi-gram"],y=top20_bigram["Freq"]);
plot.set_xticklabels(rotation=90,labels = top20_bigram["Bi-gram"]);

# %% [markdown]
# #### Tri-Gram Chart

# %%
#Tri-gram
def get_top_n3_words(corpus, n=None):
    vec1 = CountVectorizer(ngram_range=(3,3), 
           max_features=2000).fit(corpus)
    bag_of_words = vec1.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in     
                  vec1.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], 
                reverse=True)
    return words_freq[:n]

# %%
top3_words = get_top_n3_words(data["cleaned"], n=200)
top3_df = pd.DataFrame(top3_words)
top3_df.columns=["Tri-gram", "Freq"]

# %%
# Top 20 Tri gram words
top3_df.head(30)
# Out:
#                          Tri-gram  Freq
# 0                  imag imag imag  3130
# 1           trans_typ final sc_id  2264
# 2        sched_typ engi purch_sal  1897
# 3                final sc_id epmi  1793
# 4             sc_id epmi mkt_type  1793
# 5         epmi mkt_type trans_dat  1793
# 6   mkt_type trans_dat trading_sc  1793
# 7     pnt_of_intrc sched_typ engi  1793
# 8          engi purch_sal deal_no  1793
# 9                   hour bad data  1740
# 10                   bad data iso  1740
# 11             data iso trans_typ  1740
# 12            iso trans_typ final  1740
# 13                  plea let know  1688
# 14     font faceari helveticafont  1642
# 15         purch_sal deal_no hour  1560
# 16               deal_no hour bad  1560
# 17           excelr north america  1133
# 18          central standard time  1097
# 19            outlook migrat team  1063
# 20         calendar entri appoint  1052
# 21         entri appoint descript  1052
# 22     chairperson outlook migrat  1030
# 23             migrat team detail  1030
# 24           team detail descript  1030
# 25             north america corp  1017
# 26      standard time chairperson  1006
# 27       time chairperson outlook   993
# 28           insuffici disk space   967
# 29              disk space enough   967

# %%
#Tri-gram plot
import seaborn as sns
top20_trigram = top3_df.iloc[0:20,:]
fig = plt.figure(figsize = (20, 5))
plot=sns.barplot(x=top20_trigram["Tri-gram"],y=top20_trigram["Freq"]);
plot.set_xticklabels(rotation=90,labels = top20_trigram["Tri-gram"]);

# %%
d=data[['cleaned','Class']]

# %%
d
# Out:
#                                                                                                    cleaned        Class
# 0      eat shit john j lavoratoexcelr   pm john arnoldhouectect cc subject footbal bet  minn  buff  phi...      Abusive
# 1                                                                                                     fuck      Abusive
# 2      gentleman follow champagn avail  approxim retail price also interest trade red wine retail price...      Abusive
# 3      sorri taken longjust tri fend chick life sooooo hard sometim monkey brian orourkeexcelr commun  ...      Abusive
# 4      asshol john j lavoratoexcelr   john arnoldhouectect cc subject john seem make gambl problem go a...      Abusive
# ...                                                                                                    ...          ...
# 26419  need new lead busi need increas internet exposur thousand join internet daili ever sinc  reach t...  Non Abusive
# 26420  imag imag imag garth brook wrap imag imag win ticket trip garth brook show hey launcher week cou...  Non Abusive
# 26421  imageimageimag dear smartremind member imag franchoic free oneonon consult servic peopl look pur...  Non Abusive
# 26422  imag imag imag imag kid rock forev imag offici kid rock site wwwkidrockcom time get cocki hey la...  Non Abusive
# 26423  receiv email regist etrad web site one partner site want receiv partner email offer etrad market...  Non Abusive
#
# [26424 rows x 2 columns]

# %% [markdown]
# ## EDA cont......

# %% [markdown]
# ### Removing words greater than 15 characters

# %%
d['unwanted']=d['cleaned'].str.findall('\w{15,}').str.join(' ')

# %%
d[['cleaned','unwanted']]
# Out:
#                                                                                                    cleaned                            unwanted
# 0      eat shit john j lavoratoexcelr   pm john arnoldhouectect cc subject footbal bet  minn  buff  phi...                     arnoldhouectect
# 1                                                                                                     fuck
# 2      gentleman follow champagn avail  approxim retail price also interest trade red wine retail price...
# 3      sorri taken longjust tri fend chick life sooooo hard sometim monkey brian orourkeexcelr commun  ...                     arnoldhouectect
# 4      asshol john j lavoratoexcelr   john arnoldhouectect cc subject john seem make gambl problem go a...                     arnoldhouectect
# ...                                                                                                    ...                                 ...
# 26419  need new lead busi need increas internet exposur thousand join internet daili ever sinc  reach t...
# 26420  imag imag imag garth brook wrap imag imag win ticket trip garth brook show hey launcher week cou...
# 26421  imageimageimag dear smartremind member imag franchoic free oneonon consult servic peopl look pur...                   smartreminderscom
# 26422  imag imag imag imag kid rock forev imag offici kid rock site wwwkidrockcom time get cocki hey la...
# 26423  receiv email regist etrad web site one partner site want receiv partner email offer etrad market...  lcampbelexcelrcom requestimageimag
#
# [26424 rows x 2 columns]

# %%
d['cleaned_2']=d['cleaned'].str.split().map(lambda sl: " ".join(s for s in sl if len(s) < 15))

# %%
d[['cleaned','unwanted','cleaned_2']]
# Out:
#                                                                                                    cleaned  ...                                                                                            cleaned_2
# 0      eat shit john j lavoratoexcelr   pm john arnoldhouectect cc subject footbal bet  minn  buff  phi...  ...  eat shit john j lavoratoexcelr pm john cc subject footbal bet minn buff phil indi cinnci det cle...
# 1                                                                                                     fuck  ...                                                                                                 fuck
# 2      gentleman follow champagn avail  approxim retail price also interest trade red wine retail price...  ...  gentleman follow champagn avail approxim retail price also interest trade red wine retail price ...
# 3      sorri taken longjust tri fend chick life sooooo hard sometim monkey brian orourkeexcelr commun  ...  ...  sorri taken longjust tri fend chick life sooooo hard sometim monkey brian orourkeexcelr commun j...
# 4      asshol john j lavoratoexcelr   john arnoldhouectect cc subject john seem make gambl problem go a...  ...   asshol john j lavoratoexcelr john cc subject john seem make gambl problem go away bill denver jack
# ...                                                                                                    ...  ...                                                                                                  ...
# 26419  need new lead busi need increas internet exposur thousand join internet daili ever sinc  reach t...  ...  need new lead busi need increas internet exposur thousand join internet daili ever sinc reach th...
# 26420  imag imag imag garth brook wrap imag imag win ticket trip garth brook show hey launcher week cou...  ...  imag imag imag garth brook wrap imag imag win ticket trip garth brook show hey launcher week cou...
# 26421  imageimageimag dear smartremind member imag franchoic free oneonon consult servic peopl look pur...  ...  imageimageimag dear smartremind member imag franchoic free oneonon consult servic peopl look pur...
# 26422  imag imag imag imag kid rock forev imag offici kid rock site wwwkidrockcom time get cocki hey la...  ...  imag imag imag imag kid rock forev imag offici kid rock site wwwkidrockcom time get cocki hey la...
# 26423  receiv email regist etrad web site one partner site want receiv partner email offer etrad market...  ...  receiv email regist etrad web site one partner site want receiv partner email offer etrad market...
#
# [26424 rows x 3 columns]

# %%
'''
We can see the words with letters>15 have been removed from the text 

'''

# %%
print(d.iloc[0,0])
print(d.iloc[0,-1])
# Out:
# eat shit john j lavoratoexcelr   pm john arnoldhouectect cc subject footbal bet  minn  buff  phil  indi  cinnci  det  clev  den  dall  jack
# eat shit john j lavoratoexcelr pm john cc subject footbal bet minn buff phil indi cinnci det clev den dall jack

# %% [markdown]
# ### Removing some unwanted words

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
sw_nltk = stopwords.words('english')

# %%
sw_nltk.extend(['excelr','market','diamond','lavoratoexcelr','cc subject','excelronlin','north','buddi','green','turquois','original message'
,'subject','cc','image','america','corp','let','know','beckhouectect','week','fw','today','sally','new','york','said','facerial','helveticafont',
'trans_type','final','salli', 'beckhouectect','trans_typ', 'final','communicationsexcelr', 'commun','mkt_type', 'trans_dat','eric', 'basshouectect','final','sc_id',
'wednesday','dow', 'jone','sched_typ', 'engi','purch_sal','mkt_type', 'trans_dat', 'trading_sc','imag','origin','messag','sent'])

# %%
d['cleaned_3'] = d['cleaned_2'].str.split().map(lambda x: [word for word in x if word not in sw_nltk])

# %%
d['cleaned_3']=d['cleaned_3'].apply(' '.join)

# %%
d['cleaned_3']
# Out:
# 0                      eat shit john j pm john footbal bet minn buff phil indi cinnci det clev den dall jack
# 1                                                                                                       fuck
# 2        gentleman follow champagn avail approxim retail price also interest trade red wine retail price ...
# 3        sorri taken longjust tri fend chick life sooooo hard sometim monkey brian orourkeexcelr john yea...
# 4                                   asshol john j john john seem make gambl problem go away bill denver jack
#                                                         ...
# 26419    need lead busi need increas internet exposur thousand join internet daili ever sinc reach thousa...
# 26420    garth brook wrap win ticket trip garth brook show hey launcher countri king garth brook releas f...
# 26421    imageimageimag dear smartremind member franchoic free oneonon consult servic peopl look purchas ...
# 26422    kid rock forev offici kid rock site wwwkidrockcom time get cocki hey launcher muchanticip follow...
# 26423    receiv email regist etrad web site one partner site want receiv partner email offer etrad email ...
# Name: cleaned_3, Length: 26424, dtype: object

# %% [markdown]
# **Building wordcloud after removing unwanted words**

# %%
# Import packages
import matplotlib.pyplot as plt
# %matplotlib inline
from wordcloud import WordCloud, STOPWORDS
# Define a function to plot word cloud
def plot_cloud(wordcloud):
    # Set figure size
    plt.figure(figsize=(40, 30))
    # Display image
    plt.imshow(wordcloud) 
    # No axis details
    plt.axis("off");

# %%
# Joining the list into one string/text
text = ' '.join(d['cleaned_3'])

# %%
# Generate wordcloud
stopwords = STOPWORDS
stopwords.add('will')
wordcloud = WordCloud(width = 3000, height = 2000, background_color='black', max_words=100,colormap='Set2',stopwords=stopwords).generate(text)
# Plot
plot_cloud(wordcloud)

# %%
df=d[['cleaned_3','Class']]

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

# %%
df.to_csv('data_new.csv')
# !cp data_new.csv "drive/My Drive/"
